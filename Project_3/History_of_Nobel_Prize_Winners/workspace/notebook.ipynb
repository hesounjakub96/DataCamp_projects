# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Start coding here!
df = pd.read_csv("data/nobel.csv")

top_gender = df["sex"].value_counts().idxmax()
print(top_gender)

top_country = df["birth_country"].value_counts().idxmax()
print(top_country)


df["decade"] = (df["year"] // 10 )*10
df["is_usa"] = df["birth_country"] == "United States of America"
usa_per_decade = df.groupby("decade")["is_usa"].mean()

max_decade_usa = usa_per_decade.idxmax()
print(max_decade_usa)

df["decade"] = (df["year"] // 10 )*10
df["is_female"] = df["sex"] == "Female"
female_ration_per_decade_and_category = df.groupby(["decade","category"])["is_female"].mean()
max_female_dict = dict([female_ration_per_decade_and_category.idxmax()])
print(max_female_dict)
first_woman_id = df[df["is_female"]==True]["year"].idxmin()
first_woman_name = df.iloc[first_woman_id]["full_name"]
first_woman_category = df.iloc[first_woman_id]["category"]

print(first_woman_name)
print(first_woman_category)

repeat_list = df[df["full_name"].duplicated()]["full_name"].unique().tolist()
print(repeat_list)
# Out:
# Male
# United States of America
# 2000
# {2020: 'Literature'}
# Marie Curie, née Sklodowska
# Physics
# ['Marie Curie, née Sklodowska', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', 'Linus Carl Pauling', 'John Bardeen', 'Frederick Sanger', 'Office of the United Nations High Commissioner for Refugees (UNHCR)']

# %%
df.head()
# Out:
#    year    category  ... is_usa is_female
# 0  1901   Chemistry  ...  False     False
# 1  1901  Literature  ...  False     False
# 2  1901    Medicine  ...  False     False
# 3  1901       Peace  ...  False     False
# 4  1901       Peace  ...  False     False
#
# [5 rows x 21 columns]
